# %%
import sys 

REPO_DIR = '/scratch/ucgd/lustre-labs/quinlan/u6018199/tapestry'
sys.path.append(f"{REPO_DIR}/src/util") 

from read_data import read_bed_and_header

FILE_METH_FOUNDER_PHASED_ALL_CPGS = '/scratch/ucgd/lustre-labs/quinlan/data-shared/dna-methylation/CEPH1463.GRCh38.hifi.model.founder-phased.all-cpgs/NA12878.dna-methylation.founder-phased.all_cpgs.bed'
DF_METH_FOUNDER_PHASED_ALL_CPGS = read_bed_and_header(FILE_METH_FOUNDER_PHASED_ALL_CPGS)
DF_METH_FOUNDER_PHASED_ALL_CPGS
# Out:
# shape: (29_152_890, 16)
# ┌───────┬──────────┬──────────┬────────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ chrom ┆ start    ┆ end      ┆ start_hap_ ┆ … ┆ founder_ha ┆ is_within_ ┆ total_read ┆ methylatio │
# │ ---   ┆ ---      ┆ ---      ┆ map_block  ┆   ┆ plotype_ma ┆ 50bp_of_mi ┆ _count     ┆ n_level    │
# │ str   ┆ i64      ┆ i64      ┆ ---        ┆   ┆ t          ┆ smatch_sit ┆ ---        ┆ ---        │
# │       ┆          ┆          ┆ i64        ┆   ┆ ---        ┆ …          ┆ i64        ┆ f64        │
# │       ┆          ┆          ┆            ┆   ┆ str        ┆ ---        ┆            ┆            │
# │       ┆          ┆          ┆            ┆   ┆            ┆ bool       ┆            ┆            │
# ╞═══════╪══════════╪══════════╪════════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ chr1  ┆ 10470    ┆ 10471    ┆ null       ┆ … ┆ null       ┆ false      ┆ 38         ┆ 0.939      │
# ...
